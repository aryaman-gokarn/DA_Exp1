# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !pip install --upgrade xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
df=pd.read_excel('DataForFigure2.1WHR2021C2.xls')
df.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8421
# 1      Denmark     Western Europe        7.6195
# 2  Switzerland     Western Europe        7.5715
# 3      Iceland     Western Europe        7.5539
# 4  Netherlands     Western Europe        7.4640
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031646      7.904126      7.780075
# 1                        0.034657      7.687428      7.551572
# 2                        0.036243      7.642536      7.500463
# 3                        0.059373      7.670271      7.437528
# 4                        0.027326      7.517559      7.410441
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.775202        0.953603                72.000000
# 1              10.933176        0.954410                72.699753
# 2              11.117368        0.941742                74.400101
# ...

# %%
df.shape
# Out:
# (149, 20)

# %%
df.describe()
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count    149.000000                      149.000000    149.000000
# mean       5.532832                        0.058764      5.648008
# std        1.073923                        0.022011      1.054320
# min        2.522900                        0.025583      2.596468
# 25%        4.851800                        0.043369      4.991074
# 50%        5.533500                        0.054181      5.624688
# 75%        6.255400                        0.069863      6.344270
# max        7.842100                        0.172664      7.904126
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    149.000000             149.000000      149.000000
# mean       5.417655               9.432209        0.814726
# std        1.094875               1.158585        0.114892
# min        2.449332               6.635322        0.462596
# 25%        4.705666               8.540956        0.749777
# ...

# %%
df.head(10)
# Out:
#   Country name     Regional indicator  Ladder score  \
# 0      Finland         Western Europe        7.8421
# 1      Denmark         Western Europe        7.6195
# 2  Switzerland         Western Europe        7.5715
# 3      Iceland         Western Europe        7.5539
# 4  Netherlands         Western Europe        7.4640
# 5       Norway         Western Europe        7.3925
# 6       Sweden         Western Europe        7.3627
# 7   Luxembourg         Western Europe        7.3244
# 8  New Zealand  North America and ANZ        7.2766
# 9      Austria         Western Europe        7.2678
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031646      7.904126      7.780075
# 1                        0.034657      7.687428      7.551572
# 2                        0.036243      7.642536      7.500463
# 3                        0.059373      7.670271      7.437528
# 4                        0.027326      7.517559      7.410441
# ...

# %%
df.isnull().sum()
# Out:
# Country name                                  0
# Regional indicator                            0
# Ladder score                                  0
# Standard error of ladder score                0
# upperwhisker                                  0
# lowerwhisker                                  0
# Logged GDP per capita                         0
# Social support                                0
# Healthy life expectancy                       0
# Freedom to make life choices                  0
# Generosity                                    0
# Perceptions of corruption                     0
# Ladder score in Dystopia                      0
# Explained by: Log GDP per capita              0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# Dystopia + residual                           0
# ...

# %%
sns.heatmap(df.iloc[:,2:].corr(), cmap='Reds')

# %%
sns.histplot(df["Healthy life expectancy"])

# %%
df_sorted = df.sort_values('Healthy life expectancy')
x=df_sorted['Country name'].values
y=df_sorted['Healthy life expectancy'].values
fig, ax = plt.subplots(figsize =(12,30))   

ax.barh(x, y, color='red', edgecolor=(0,0,0),data=df_sorted) 
# ax.set_title('Horse Power') 
plt.show()
